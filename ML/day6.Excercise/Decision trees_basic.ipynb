# %%
from matplotlib.colors import ListedColormap
from matplotlib import pyplot as plt
from sklearn import tree
import numpy as np

# %%
iris = load_iris()
X = iris.data[:, 2:] # petal length and width # Features
y = iris.target   # true y, lable, target  

np.unique(y)
# Out:
# array([0, 1, 2])

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier.fit/
my_model = tree.DecisionTreeClassifier(  # Estimator (the learing algorhtim)
    max_depth=2, # Reguliazation defines the max depth of the tree for all branches
    # max_leaf_nodes=5 # Another hyper-paramter that control the Regulization by limited the max sample in the leave (last node)
    # random_state=42 # Optional (to create re-produciablity) 
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
model.predict([
                    [1.7, 1.9], # Never-seen data point 1
                    [9, 1.7], # Never-seen data point 2
                ])
# Out:
# array([0, 2])

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy", accuracy)
# Out:
# Accuracy 1.0

# %%
plt.figure(figsize=(15, 10))
tree.plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.title("Decision Tree Visualization")
plt.show()
