# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = 6* np.random.rand(100, 1) - 6
y = 0.3 * X**2 + X + 2 + np.random.randn(100, 1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)

# %%
model = LinearRegression()
model.fit(X, y)
y_hat = model.predict(X)
print("OLS Intercept:", model.intercept_)
print("OLS Coefficient:", model.coef_)
print("OLS MSE:", mean_squared_error(y, y_hat))
# Out:
# OLS Intercept: [-0.16049362]
# OLS Coefficient: [[-0.91388043]]
# OLS MSE: 1.5959217938475831

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X, y)
ax.plot(X, y_hat)
