# %%
pip install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pydot
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing>=3.1.0 in /opt/conda/envs/py39_ml/lib/python3.9/site-packages (from pydot) (3.2.0)
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Installing collected packages: pydot
# Successfully installed pydot-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

import pydot as py
# Out:
# 2025-06-26 11:18:49.293043: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 11:18:49.376539: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 11:18:49.453490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750922329.552423  319997 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750922329.561394  319997 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750922329.643814  319997 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750922329.643953  319997 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750922329.643957  319997 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750922329.643959  319997 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-26 11:18:49.658581: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
i_layer = tf.keras.layers.Input([6,])
layer1 = tf.keras.layers.Dense(100)
layer2 = tf.keras.layers.Dense(64)
layer3 = tf.keras.layers.Dense(32)
layer4 = tf.keras.layers.Dense(16)
o_layer = tf.keras.layers.Dense(1)

# %%
x = layer1(i_layer)
z = layer2(x)
b = layer3(z)
a = layer4(b)
out = o_layer(a)
# Out:
# 2025-06-26 11:18:54.652866: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model = tf.keras.Model(inputs=i_layer, outputs=out)

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, rankdir="TB", dpi=96)
